# %% [markdown]
# ![image.png](attachment:image.png)
# * 링크 : https://www.acmicpc.net/problem/10872

# %%
''' 내가 품 '''
result = 1
for i in range(int(input()),0, -1): result *= i
print(result)
# Out:
# 10
# 3628800

# %%
suma=1
for i in range(1, int(input())+1):
    suma *= i
print(suma)
# Out:
# 10
# 3628800

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
''' 다른 사람이 품 - 숏코딩 '''
import math
print(math.factorial(int(input())))
# Out:
# 10
# 3628800
