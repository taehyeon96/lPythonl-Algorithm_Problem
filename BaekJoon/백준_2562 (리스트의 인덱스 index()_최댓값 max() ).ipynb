# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
#
# * 링크 : https://www.acmicpc.net/problem/2562

# %%
''' 내가 품 '''
lst = [int(input()) for _ in range(9)]

print(max(lst), '\n', lst.index(max(lst))+1, sep='')
# Out:
# 3
# 29
# 38
# 12
# 57
# 74
# 40
# 85
# 61
# 85
# 8

# %% [markdown]
# ![image.png](attachment:image.png)
