# %% [markdown]
# ### 메모한 것
#
# 4가지 항목 반드시 선택
#     - 개발언어 항목 : cpp, java, python
#     - 지원 직군 항목 : backend와 frontend
#     - 지원 경력구분 항목 : junior와 senior
#     - 소울푸드 항목 : chicken과 pizza
#
#
# 지원자 조건을 선택해 그에 맞는 사람이 몇 명인지 EX)
# * [조건]을 만족하는 사람 중 코딩테스트 점수를 X점 이상 받은 사람은 모두 몇 명인가?
#     - 코딩테스트에 java로 참여했으며,
#     - backend 직군을 선택했고,
#     - junior 경력이면서,
#     - 소울푸드로 pizza를 선택한 사람 중
#     - 코딩테스트 점수를 50점 이상 받은 지원자는 몇 명인가?
#
#
#
# input
#     - info : 4가지의 정보와 획득한 코딩테스트 점수를 하나의 문자열로 구성한 값의 배열
#         * 일종의 DB로 저장해야할듯 (-> 딕셔너리???)
#         * "개발언어 직군 경력 소울푸드 점수" 형식
#         * 각 단어는 공백문자(스페이스 바) 하나로 구분되어 있습니다.
#
#     - query : 문의조건이 문자열 형태로 담긴 배열
#         * "개발언어 and 직군 and 경력 and 소울푸드" 형식의 문자열
#         * 각 단어는 공백문자(스페이스 바) 하나로 구분되어 있습니다.
#         * '-' 표시는 해당 조건을 고려하지 않겠다는 의미입니다. (=전부 포함)
# output
#     - 각 문의조건에 해당하는 사람들의 숫자를 순서대로 배열에 담아 return
#
# ### 내 생각
#
# 효율성 따지려면 -> 검색속도 빠르게 = pruning 한번에 크게 = 이진분류가 큰 컬럼부터 pruning하면 될 것 같은데
# 쿼리에 '-'가 있는 경우 -> 해당 컬럼에 대해 걸러내지 말고 전부 포함
#
# ### 알고리즘

# %%
''' '-'를 신경쓰지 않은 경우까지 성공하였음 '''
def preprocessing(infos, queries):
    info = []
    query = []
    
    # 전처리
    for i in infos:
        info.append(i.split(' '))   # 단어단위로 우선 저장
        
    for i in queries:
        query.append(i.split(' and '))  
        
    for i in query:     
        tmp1, tmp2 = i.pop().split(' ')
        i.append(tmp1)
        i.append(tmp2)
    
    return info, query

def solution(infos, queries):
    answer = []
    ans = 0
    
    info, query = preprocessing(infos, queries)
    print(info)
    print()
    print(query)
    
    for sql in query:
        for data in info:
            # '-'를 신경쓰지 않은 경우
            if int(sql[-1]) < int(data[-1]) and sql[:4] == data[:4]:
                print("\n", data)
                ans += 1
        
        answer.append(ans)
        ans = 0
        
        
            # 각 조건에 맞는 걸 하나씩 체크한 결과를 여기에 이제 최종 answer.append(숫자)
    
    return answer

info = ["java backend junior pizza 150","python frontend senior chicken 210","python frontend senior chicken 150","cpp backend senior pizza 260","java backend junior chicken 80","python backend senior chicken 50"]
query = ["java and backend and junior and pizza 100","python and frontend and senior and chicken 200","cpp and - and senior and pizza 250","- and backend and senior and - 150","- and - and - and chicken 100","- and - and - and - 150"]
print(solution(info, query))
# Out:
# [['java', 'backend', 'junior', 'pizza', '150'], ['python', 'frontend', 'senior', 'chicken', '210'], ['python', 'frontend', 'senior', 'chicken', '150'], ['cpp', 'backend', 'senior', 'pizza', '260'], ['java', 'backend', 'junior', 'chicken', '80'], ['python', 'backend', 'senior', 'chicken', '50']]
#
# [['java', 'backend', 'junior', 'pizza', '100'], ['python', 'frontend', 'senior', 'chicken', '200'], ['cpp', '-', 'senior', 'pizza', '250'], ['-', 'backend', 'senior', '-', '150'], ['-', '-', '-', 'chicken', '100'], ['-', '-', '-', '-', '150']]
#
#  ['java', 'backend', 'junior', 'pizza', '150']
#
#  ['python', 'frontend', 'senior', 'chicken', '210']
# [1, 1, 0, 0, 0, 0]

# %%
''' '-'를 신경쓴 경우를 해야함 '''
def preprocessing(infos, queries):
    info = []
    query = []
    
    # 전처리
    for i in infos:
        info.append(i.split(' '))   # 단어단위로 우선 저장
        
    for i in queries:
        query.append(i.split(' and '))  
        
    for i in query:     
        tmp1, tmp2 = i.pop().split(' ')
        i.append(tmp1)
        i.append(tmp2)
    
    return info, query

def solution(infos, queries):
    answer = []
    ans = 0
    
    info, query = preprocessing(infos, queries)
    print(info)
    print()
    print(query)
    
    minus_num = 0
    
    for sql in query:
        for data in info:
            # '-'를 고려한 경우(+ 점수가 더 높은 것 중)
            if '-' in sql and int(sql[-1]) < int(data[-1]):
                print("\n", data)
                print(sql)
                for i in range(4):    # 마지막 점수 제외
                    if sql[i] != '-' and sql[i] == data[i]:
                        minus_num += 1
                        
                print(4 - minus_num, "    ", sql.count('-'))
                
                if (4 - minus_num) == sql.count('-'):
                    ans += 1
                minus_num = 0
                        
                
            # '-'를 고려하지 않은 경우
            elif int(sql[-1]) < int(data[-1]) and sql[:4] == data[:4]:
                print("\n", data)
                ans += 1
        
        
        answer.append(ans)    # 각 조건에 맞는 걸 하나씩 체크한 결과를 여기에 이제 최종 answer.append(숫자)
        ans = 0
        print("------------------------------------------------------------")
    return answer

info = ["java backend junior pizza 150","python frontend senior chicken 210","python frontend senior chicken 150","cpp backend senior pizza 260","java backend junior chicken 80","python backend senior chicken 50"]
query = ["java and backend and junior and pizza 100","python and frontend and senior and chicken 200","cpp and - and senior and pizza 250","- and backend and senior and - 150","- and - and - and chicken 100","- and - and - and - 150"]
print(solution(info, query))
# Out:
# [['java', 'backend', 'junior', 'pizza', '150'], ['python', 'frontend', 'senior', 'chicken', '210'], ['python', 'frontend', 'senior', 'chicken', '150'], ['cpp', 'backend', 'senior', 'pizza', '260'], ['java', 'backend', 'junior', 'chicken', '80'], ['python', 'backend', 'senior', 'chicken', '50']]
#
# [['java', 'backend', 'junior', 'pizza', '100'], ['python', 'frontend', 'senior', 'chicken', '200'], ['cpp', '-', 'senior', 'pizza', '250'], ['-', 'backend', 'senior', '-', '150'], ['-', '-', '-', 'chicken', '100'], ['-', '-', '-', '-', '150']]
#
#  ['java', 'backend', 'junior', 'pizza', '150']
# ------------------------------------------------------------
#
#  ['python', 'frontend', 'senior', 'chicken', '210']
# ------------------------------------------------------------
#
#  ['cpp', 'backend', 'senior', 'pizza', '260']
# ['cpp', '-', 'senior', 'pizza', '250']
# 1      1
# ------------------------------------------------------------
#
#  ['python', 'frontend', 'senior', 'chicken', '210']
# ['-', 'backend', 'senior', '-', '150']
# 3      2
#
#  ['cpp', 'backend', 'senior', 'pizza', '260']
# ['-', 'backend', 'senior', '-', '150']
# 2      2
# ------------------------------------------------------------
#
#  ['java', 'backend', 'junior', 'pizza', '150']
# ['-', '-', '-', 'chicken', '100']
# 4      3
#
#  ['python', 'frontend', 'senior', 'chicken', '210']
# ['-', '-', '-', 'chicken', '100']
# 3      3
#
#  ['python', 'frontend', 'senior', 'chicken', '150']
# ['-', '-', '-', 'chicken', '100']
# 3      3
#
#  ['cpp', 'backend', 'senior', 'pizza', '260']
# ['-', '-', '-', 'chicken', '100']
# 4      3
# ------------------------------------------------------------
#
#  ['python', 'frontend', 'senior', 'chicken', '210']
# ['-', '-', '-', '-', '150']
# 4      4
#
#  ['cpp', 'backend', 'senior', 'pizza', '260']
# ['-', '-', '-', '-', '150']
# 4      4
# ------------------------------------------------------------
# [1, 1, 1, 1, 2, 2]

# %%
''' 정답 - 정확성은 다 맞고 효율성은 다 틀린 ver '''
def preprocessing(infos, queries):
    info = []
    query = []
    
    # 전처리  -> 다음부턴 query.replace(" and ", "") 를 사용하도록 하자..
    for i in infos:
        info.append(i.split(' '))   # 단어단위로 우선 저장
        
    for i in queries:
        query.append(i.split(' and '))  
        
    for i in query:     
        tmp1, tmp2 = i.pop().split(' ')
        i.append(tmp1)
        i.append(tmp2)
    
    return info, query

def solution(infos, queries):
    answer = []
    ans = 0
    minus_num = 0
    
    info, query = preprocessing(infos, queries)
    
    for sql in query:
        for data in info:            
            # '-'를 고려한 경우(+ 점수가 더 높은 것 중)
            if '-' in sql and int(sql[-1]) <= int(data[-1]):
                for i in range(4):                                       # 마지막 점수 제외
                    if sql[i] != '-' and sql[i] == data[i]:
                        minus_num += 1
                        
                if (4 - minus_num) == sql.count('-'):
                    ans += 1
                minus_num = 0                        
                
            # '-'를 고려하지 않은 경우
            elif int(sql[-1]) <= int(data[-1]) and sql[:4] == data[:4]:
                ans += 1        
        
        answer.append(ans)                                                # 각 조건에 맞는 걸 하나씩 체크한 결과를 여기에 이제 최종 answer.append(숫자)
        ans = 0
        
    return answer

info = ["java backend junior pizza 150","python frontend senior chicken 210","python frontend senior chicken 150","cpp backend senior pizza 260","java backend junior chicken 80","python backend senior chicken 50"]
query = ["java and backend and junior and pizza 100","python and frontend and senior and chicken 200","cpp and - and senior and pizza 250","- and backend and senior and - 150","- and - and - and chicken 100","- and - and - and - 150"]
print(solution(info, query))
# Out:
# [1, 1, 1, 1, 2, 4]

# %%
arr = ['-', 'backend', 'senior', '-', '150']
print(arr.count('-'))
# Out:
# 2

# %%
def solution(infos, queries):
    answer = []

    # 총 경우의 수 (108가지)
    info_dict = {}

    for lang in ['cpp', 'java', 'python', "-"]:
        for job in ['backend', 'frontend', "-"]:
            for career in ['junior', 'senior', "-"]:
                for food in ['chicken', 'pizza', "-"]:
                    info_dict[lang + job + career + food] = []
    
    # 지원자의 경우의 수 (1인, 16가지)
    for info in infos:
        info = info.split(" ")
        for lang in [info[0], "-"]:
            for job in [info[1], "-"]:
                for career in [info[2], "-"]:
                    for food in [info[3], "-"]:
                        info_dict[lang + job + career + food].append(int(info[4]))

    # 시간초과를 해결한 방법
    for key in info_dict.keys():
        info_dict[key].sort()

    # 조건
    for query in queries:
        query = query.replace(" and ", "")
        query = query.split()

        query_score = int(query[1])
        query = query[0]

        # 점수
        info_score = sorted(info_dict[query])  # 시간초과가 나는 이유
        l = len(info_score)
        tmp = l

        low, high = 0, l - 1

        while low <= high:
            mid = (low + high) // 2

            if query_score <= info_score[mid]:
                tmp = mid
                high = mid - 1

            else:
                low = mid + 1

        answer.append(l - tmp)
    return answer


print(solution(["java backend junior pizza 150","python frontend senior chicken 210","python frontend senior chicken 150","cpp backend senior pizza 260","java backend junior chicken 80","python backend senior chicken 50"],
         ["java and backend and junior and pizza 100","python and frontend and senior and chicken 200","cpp and - and senior and pizza 250","- and backend and senior and - 150","- and - and - and chicken 100","- and - and - and - 150"]))
